# %%
import nufit as nu
import numpy as np
import matplotlib.pyplot as plt

# %%
nu.make_LambdaCDM_Pk("LambdaCDM")

# %%
LambdaCDM = np.load("LambdaCDM.npz", allow_pickle=True)

# %%
LambdaCDM.files
# Out:
# ['results_dictionary', 'k_array', 'Pk_LambdaCDM']

# %%
plt.figure()
plt.loglog(LambdaCDM['k_array'], LambdaCDM['Pk_LambdaCDM'])

# %%
LambdaCDM['results_dictionary']
# Out:
# array({'age': 13.770597734385982, 'Neff': 3.0440000000000005, 'omega_b': 0.0223828, 'Omega0_cdm': 0.26120569320189113, 'h': 0.6781, 'Omega0_k': 0.0, 'Omega0_m': 0.30988304299999997, 'Omega_b': 0.048677349798108865, 'Omega_g': 5.378150968509925e-05, 'Omega_lambda': 0.6900259955434282, 'Omega_m': 0.30988304299999997, 'Omega_r': 9.096145657179167e-05, 'rs_drag': 147.0716138462091, 'Sigma8': 0.8250066476522795, 'Sigma8_cb': 0.8250066476522795, 'T_cmb': 2.7255, 'theta_s_100': 1.041798088420396, 'theta_star_100': 1.0441456300191327, 'n_s': 0.9660499, 'tau_reio': 0.05430842},
#       dtype=object)

# %%
nu.v_masses_std(0.1, True, "100meV")

# %%
nures = np.load("100meV.npz", allow_pickle=True)

# %%
nures.files
# Out:
# ['results_dictionary',
#  'k_n_array',
#  'Pk_n_array',
#  'normal_hierarchy',
#  'm1',
#  'm2',
#  'm3',
#  'm_small',
#  'sum_nu']

# %%
nures['results_dictionary']
# Out:
# array({'age': 13.772631796298999, 'Neff': 3.0440046643602963, 'omega_b': 0.0223828, 'Omega0_cdm': 0.25392116301446943, 'h': 0.6781, 'Omega0_k': 0.0, 'Omega0_m': 0.30988279583172007, 'Omega_b': 0.048677349798108865, 'Omega_g': 5.378150968509925e-05, 'Omega_lambda': 0.6900631216258057, 'Omega_m': 0.30988279583172007, 'Omega_r': 5.408254247411832e-05, 'rs_drag': 147.901411373083, 'Sigma8': 0.748369030190994, 'Sigma8_cb': 0.7640116241712596, 'T_cmb': 2.7255, 'theta_s_100': 1.0465823060951929, 'theta_star_100': 1.048975265555097, 'n_s': 0.9660499, 'tau_reio': 0.05430842},
#       dtype=object)

# %%
plt.figure()
plt.semilogx(nures['k_n_array'], (nures['Pk_n_array']-LambdaCDM['Pk_LambdaCDM'])/LambdaCDM['Pk_LambdaCDM'])
