# %%
import numpy as np
import matplotlib.pyplot as plt
import nufit

# %%
file_names = [
    "mass-300-life-0.010.npz", 
    "mass-300-life-0.013.npz",
    "mass-300-life-0.017.npz",
    "mass-300-life-0.022.npz",
    "mass-300-life-0.030.npz",
    "mass-300-life-0.040.npz",
    "mass-300-life-0.053.npz",
    "mass-300-life-0.070.npz",
    "mass-300-life-0.093.npz",
    "mass-300-life-0.122.npz",
    "mass-300-life-0.166.npz",
    "mass-300-life-0.221.npz",
    "mass-300-life-0.282.npz",
    "mass-300-life-0.373.npz",
    "mass-300-life-0.517.npz",
    "mass-300-life-0.664.npz",
    "mass-300-life-0.912.npz",
    "mass-300-life-1.236.npz",
    "mass-300-life-1.495.npz",
    "mass-300-life-1.846.npz"
]

# %%
for name in file_names:
    nufit.v_masses_sterile(0.1, True, f"RMFK_Results/{name}", "test", make_plot=True, sum_mnu_filename=True)
    model = np.load("test312.npz", allow_pickle = True)
    print(f"Model Neff: {model['n_results'].item()['Neff']}")
    data = np.load('RMFK_Results/mass-300-life-0.010.npz')
    print(f"Data Neff: {data['neff']}")
# Out:
# Model Neff: 3.040090444671053
# Data Neff: 3.0401751672388007
# Model Neff: 3.037998330321379
# Data Neff: 3.0401751672388007
# Model Neff: 3.03307418270413
# Data Neff: 3.0401751672388007
# Model Neff: 3.0216231502635407
# Data Neff: 3.0401751672388007
# Model Neff: 2.997461029606007
# Data Neff: 3.0401751672388007
# Model Neff: 2.9485681199131393
# Data Neff: 3.0401751672388007
# Model Neff: 2.887247091328492
# Data Neff: 3.0401751672388007
# Model Neff: 2.79422062696113
# Data Neff: 3.0401751672388007
# Model Neff: 2.6775073763183337
# Data Neff: 3.0401751672388007
# Model Neff: 2.56765207479223
# Data Neff: 3.0401751672388007
# Model Neff: 2.4372465257523364
# Data Neff: 3.0401751672388007
# Running CLASS version v3.3.0
# Computing background
#  -> non-cold dark matter species with i=1 has m_i = 1.000000e-01 eV (so m_i / omega_i =9.308810e+01 eV)
#  -> ncdm species i=1 sampled with 10 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.01336
#  -> non-cold dark matter species with i=2 has m_i = 1.003693e-01 eV (so m_i / omega_i =9.308811e+01 eV)
#  -> ncdm species i=2 sampled with 10 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.01336
#  -> non-cold dark matter species with i=3 has m_i = 1.116154e-01 eV (so m_i / omega_i =9.308843e+01 eV)
#  -> ncdm species i=3 sampled with 10 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.01336
#  -> age = 13.772635 Gyr
#  -> conformal age = 14167.422734 Mpc
#  -> N_eff = 3.04009 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3337.317068
#     corresponding to conformal time = 115.103744 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> age = 13.770601 Gyr
#  -> conformal age = 14151.967733 Mpc
#  -> N_eff = 3.04009 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3407.540479
#     corresponding to conformal time = 112.693310 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> non-cold dark matter species with i=1 has m_i = 1.000000e-01 eV (so m_i / omega_i =9.321395e+01 eV)
#  -> ncdm species i=1 sampled with 8 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.01267
#  -> non-cold dark matter species with i=2 has m_i = 1.003693e-01 eV (so m_i / omega_i =9.321396e+01 eV)
#  -> ncdm species i=2 sampled with 8 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.01267
#  -> non-cold dark matter species with i=3 has m_i = 1.116154e-01 eV (so m_i / omega_i =9.321429e+01 eV)
#  -> ncdm species i=3 sampled with 8 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.01267
#  -> age = 13.772635 Gyr
#  -> conformal age = 14167.445802 Mpc
#  -> N_eff = 3.038 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3338.333158
#     corresponding to conformal time = 115.084764 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> age = 13.770602 Gyr
#  -> conformal age = 14152.005063 Mpc
#  -> N_eff = 3.038 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3408.498806
#     corresponding to conformal time = 112.677471 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> non-cold dark matter species with i=1 has m_i = 1.000000e-01 eV (so m_i / omega_i =9.335304e+01 eV)
#  -> ncdm species i=1 sampled with 8 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.01102
#  -> non-cold dark matter species with i=2 has m_i = 1.003693e-01 eV (so m_i / omega_i =9.335305e+01 eV)
#  -> ncdm species i=2 sampled with 8 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.01102
#  -> non-cold dark matter species with i=3 has m_i = 1.116154e-01 eV (so m_i / omega_i =9.335337e+01 eV)
#  -> ncdm species i=3 sampled with 8 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.01102
#  -> age = 13.772635 Gyr
#  -> conformal age = 14167.510666 Mpc
#  -> N_eff = 3.03307 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3340.644052
#     corresponding to conformal time = 115.043169 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> age = 13.770606 Gyr
#  -> conformal age = 14152.092946 Mpc
#  -> N_eff = 3.03307 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3410.756499
#     corresponding to conformal time = 112.640184 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> non-cold dark matter species with i=1 has m_i = 1.000000e-01 eV (so m_i / omega_i =9.396601e+01 eV)
#  -> ncdm species i=1 sampled with 8 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.00721
#  -> non-cold dark matter species with i=2 has m_i = 1.003693e-01 eV (so m_i / omega_i =9.396602e+01 eV)
#  -> ncdm species i=2 sampled with 8 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.00721
#  -> non-cold dark matter species with i=3 has m_i = 1.116154e-01 eV (so m_i / omega_i =9.396635e+01 eV)
#  -> ncdm species i=3 sampled with 8 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 1.00721
#  -> age = 13.772636 Gyr
#  -> conformal age = 14167.641973 Mpc
#  -> N_eff = 3.02162 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3346.214428
#     corresponding to conformal time = 114.939820 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> age = 13.770614 Gyr
#  -> conformal age = 14152.297432 Mpc
#  -> N_eff = 3.02162 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3416.018315
#     corresponding to conformal time = 112.553424 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> non-cold dark matter species with i=1 has m_i = 1.000000e-01 eV (so m_i / omega_i =9.495257e+01 eV)
#  -> ncdm species i=1 sampled with 8 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.999154
#  -> non-cold dark matter species with i=2 has m_i = 1.003693e-01 eV (so m_i / omega_i =9.495258e+01 eV)
#  -> ncdm species i=2 sampled with 8 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.999154
#  -> non-cold dark matter species with i=3 has m_i = 1.116154e-01 eV (so m_i / omega_i =9.495292e+01 eV)
#  -> ncdm species i=3 sampled with 8 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.999154
#  -> age = 13.772637 Gyr
#  -> conformal age = 14167.941640 Mpc
#  -> N_eff = 2.99746 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3357.815835
#     corresponding to conformal time = 114.729019 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> age = 13.770632 Gyr
#  -> conformal age = 14152.729434 Mpc
#  -> N_eff = 2.99746 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3427.174406
#     corresponding to conformal time = 112.370137 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> non-cold dark matter species with i=1 has m_i = 1.000000e-01 eV (so m_i / omega_i =9.662721e+01 eV)
#  -> ncdm species i=1 sampled with 8 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.982856
#  -> non-cold dark matter species with i=2 has m_i = 1.003693e-01 eV (so m_i / omega_i =9.662722e+01 eV)
#  -> ncdm species i=2 sampled with 8 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.982856
#  -> non-cold dark matter species with i=3 has m_i = 1.116154e-01 eV (so m_i / omega_i =9.662756e+01 eV)
#  -> ncdm species i=3 sampled with 8 (resp. 3) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.982856
#  -> age = 13.772641 Gyr
#  -> conformal age = 14168.574822 Mpc
#  -> N_eff = 2.94857 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3381.290544
#     corresponding to conformal time = 114.310009 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> age = 13.770668 Gyr
#  -> conformal age = 14153.605822 Mpc
#  -> N_eff = 2.94857 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3449.973458
#     corresponding to conformal time = 111.998332 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> non-cold dark matter species with i=1 has m_i = 1.000000e-01 eV (so m_i / omega_i =9.923759e+01 eV)
#  -> ncdm species i=1 sampled with 8 (resp. 5) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.962416
#  -> non-cold dark matter species with i=2 has m_i = 1.003693e-01 eV (so m_i / omega_i =9.923760e+01 eV)
#  -> ncdm species i=2 sampled with 8 (resp. 5) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.962416
#  -> non-cold dark matter species with i=3 has m_i = 1.116154e-01 eV (so m_i / omega_i =9.923796e+01 eV)
#  -> ncdm species i=3 sampled with 8 (resp. 5) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.962416
#  -> age = 13.772644 Gyr
#  -> conformal age = 14169.346415 Mpc
#  -> N_eff = 2.88725 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3411.432148
#     corresponding to conformal time = 113.774323 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> age = 13.770713 Gyr
#  -> conformal age = 14154.709209 Mpc
#  -> N_eff = 2.88725 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3479.000085
#     corresponding to conformal time = 111.530265 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> non-cold dark matter species with i=1 has m_i = 1.000000e-01 eV (so m_i / omega_i =1.028218e+02 eV)
#  -> ncdm species i=1 sampled with 8 (resp. 5) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.931407
#  -> non-cold dark matter species with i=2 has m_i = 1.003693e-01 eV (so m_i / omega_i =1.028218e+02 eV)
#  -> ncdm species i=2 sampled with 8 (resp. 5) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.931407
#  -> non-cold dark matter species with i=3 has m_i = 1.116154e-01 eV (so m_i / omega_i =1.028221e+02 eV)
#  -> ncdm species i=3 sampled with 8 (resp. 5) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.931407
#  -> age = 13.772650 Gyr
#  -> conformal age = 14170.562352 Mpc
#  -> N_eff = 2.79422 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3457.784056
#     corresponding to conformal time = 112.970907 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> age = 13.770782 Gyr
#  -> conformal age = 14156.392204 Mpc
#  -> N_eff = 2.79422 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3523.978974
#     corresponding to conformal time = 110.816415 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> non-cold dark matter species with i=1 has m_i = 1.000000e-01 eV (so m_i / omega_i =1.075884e+02 eV)
#  -> ncdm species i=1 sampled with 8 (resp. 5) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.892502
#  -> non-cold dark matter species with i=2 has m_i = 1.003693e-01 eV (so m_i / omega_i =1.075884e+02 eV)
#  -> ncdm species i=2 sampled with 8 (resp. 5) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.892502
#  -> non-cold dark matter species with i=3 has m_i = 1.116154e-01 eV (so m_i / omega_i =1.075888e+02 eV)
#  -> ncdm species i=3 sampled with 8 (resp. 5) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.892502
#  -> age = 13.772658 Gyr
#  -> conformal age = 14172.107898 Mpc
#  -> N_eff = 2.67751 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3517.614463
#     corresponding to conformal time = 111.959343 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> age = 13.770868 Gyr
#  -> conformal age = 14158.519561 Mpc
#  -> N_eff = 2.67751 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3582.082112
#     corresponding to conformal time = 109.914245 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> non-cold dark matter species with i=1 has m_i = 1.000000e-01 eV (so m_i / omega_i =1.123037e+02 eV)
#  -> ncdm species i=1 sampled with 8 (resp. 5) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.855884
#  -> non-cold dark matter species with i=2 has m_i = 1.003693e-01 eV (so m_i / omega_i =1.123037e+02 eV)
#  -> ncdm species i=2 sampled with 8 (resp. 5) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.855884
#  -> non-cold dark matter species with i=3 has m_i = 1.116154e-01 eV (so m_i / omega_i =1.123041e+02 eV)
#  -> ncdm species i=3 sampled with 8 (resp. 5) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.855884
#  -> age = 13.772666 Gyr
#  -> conformal age = 14173.586673 Mpc
#  -> N_eff = 2.56765 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3575.678020
#     corresponding to conformal time = 111.004471 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> age = 13.770949 Gyr
#  -> conformal age = 14160.538375 Mpc
#  -> N_eff = 2.56765 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3638.548710
#     corresponding to conformal time = 109.058268 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> non-cold dark matter species with i=1 has m_i = 1.000000e-01 eV (so m_i / omega_i =1.182086e+02 eV)
#  -> ncdm species i=1 sampled with 8 (resp. 5) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.812416
#  -> non-cold dark matter species with i=2 has m_i = 1.003693e-01 eV (so m_i / omega_i =1.182086e+02 eV)
#  -> ncdm species i=2 sampled with 8 (resp. 5) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.812416
#  -> non-cold dark matter species with i=3 has m_i = 1.116154e-01 eV (so m_i / omega_i =1.182090e+02 eV)
#  -> ncdm species i=3 sampled with 8 (resp. 5) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.812416
#  -> age = 13.772675 Gyr
#  -> conformal age = 14175.372476 Mpc
#  -> N_eff = 2.43725 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3646.922782
#     corresponding to conformal time = 109.867097 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> age = 13.771045 Gyr
#  -> conformal age = 14162.956096 Mpc
#  -> N_eff = 2.43725 (summed over all species that are non-relativistic at early times)
#  -> radiation/matter equality at z = 3707.932666
#     corresponding to conformal time = 108.033361 Mpc
# Running CLASS version v3.3.0
# Computing background
#  -> non-cold dark matter species with i=1 has m_i = 1.000000e-01 eV (so m_i / omega_i =1.222843e+02 eV)
#  -> ncdm species i=1 sampled with 8 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.779462
#  -> non-cold dark matter species with i=2 has m_i = 1.003693e-01 eV (so m_i / omega_i =1.222843e+02 eV)
#  -> ncdm species i=2 sampled with 8 (resp. 6) points for purpose of background (resp. perturbation) integration. In the relativistic limit it gives Delta N_eff = 0.779462
#  -> non-cold dark matter species with i=3 has m_i = 1.116154e-01 eV (so m_i / omega_i =1.222848e+02
# Model Neff: 2.3383847431955442
# Data Neff: 3.0401751672388007
# Model Neff: 2.289945235222621
# Data Neff: 3.0401751672388007
# Model Neff: 2.371681180175127
# Data Neff: 3.0401751672388007
# Model Neff: 2.4457413669601342
# Data Neff: 3.0401751672388007
# Model Neff: 2.5595246794348014
# Data Neff: 3.0401751672388007
# Model Neff: 2.7574068171034543
# Data Neff: 3.0401751672388007
# /Users/eddily/Pk_fit/nufit.py:143: RuntimeWarning: overflow encountered in exp
#   return eps**2 / (np.exp(eps/T) + 1)
# Model Neff: 3.1832388292671725
# Data Neff: 3.0401751672388007
# Model Neff: 3.326164322955487
# Data Neff: 3.0401751672388007
# Model Neff: 3.4898859470481605
# Data Neff: 3.0401751672388007
